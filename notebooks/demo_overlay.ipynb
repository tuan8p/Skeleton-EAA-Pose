# %% [markdown]
# # Demo Overlay - ve skeleton len video goc

# %%
# Cell 1: Lay code moi nhat tu GitHub (nhanh dai)
import os
REPO = "https://github.com/tuan8p/Skeleton-EAA-Pose.git"
BRANCH = "dai"
WORKDIR = "/content/Skeleton-EAA-Pose"
if not os.path.isdir(WORKDIR):
    # !git clone -b {BRANCH} {REPO} {WORKDIR}
else:
    # !git -C {WORKDIR} pull origin {BRANCH}
# %cd {WORKDIR}

# %%
# Cell 2: Cai dat thu vien
# !pip install -q opencv-python numpy

# %%
# Cell 3: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Cell 4: Chinh path va tao video overlay
from src.demo_overlay import create_overlay_video
create_overlay_video(
    video_path='/content/drive/MyDrive/PKU-MMD/RGB_PKUMMDv1/0002-L.avi',
    skeleton_file='/content/drive/MyDrive/skeletons/0002-L_000.npy',
    metadata_file='/content/drive/MyDrive/skeletons/0002-L_000.jsonl',
    output_video='/content/drive/MyDrive/overlay/0002-L_overlay.mp4',
    joint_color=(0, 255, 0),
    line_color=(0, 0, 255),
)
print('done')
